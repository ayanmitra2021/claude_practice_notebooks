# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

def add_user_message(messages, text):
    user_message = {"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant", "content":text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0,stop_sequences=None):  
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    
    if system:
        params["system"] = system

    message = client.messages.create(**params)
    
    return message.content[0].text

# %%
messages =[]

add_user_message(messages, "How do I solve 5x+3=2 for x? ")

system ="""
You are patient math tutor. 
Do not directly answer a student's question. 
Guide them to a solution step by step.
"""
answer = chat(messages, system=system)

print(answer)
# Out:
# Great question! Let's work through this step by step.
#
# **Step 1:** Look at the equation: 5x + 3 = 2
#
# Your goal is to get x by itself on one side. What do you think you should do first to start isolating x?
#
# *Hint: Think about what's being added to the 5x term.*
#
# Once you tell me what you'd do, we can move to the next step!

# %%
messages =[]

add_user_message(messages, "Write a python function to check a string for duplicate characters.")

system ="""
You are seasoned python developer. 
You only write the code precisely for the task, without any other comments or metadata.
"""
answer = chat(messages, system=system)

print(answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 messages =[]
# ----> 3 add_user_message(messages, "Write a python function to check a string for duplicate characters.")
#       5 system ="""
#       6 You are seasoned python developer.
#       7 You only write the code precisely for the task, without any other comments or metadata.
#       8 """
#       9 answer = chat(messages, system=system)
#
# NameError: name 'add_user_message' is not defined

# %%
messages =[]

add_user_message(
    messages, 
    "Generate a one sentence Hindi movie idea"
)

answer = chat(messages, temperature=1.0)

print(answer)
# Out:
# # Hindi Movie Idea
#
# एक आम शहरी लड़की जब अपने पिता की रहस्यमय मौत का सच जानने के लिए निकलती है, तो उसे अपने शहर के सबसे ताकतवर माफिया बॉस से लड़ना पड़ता है।
#
# *(A common city girl must confront her city's most powerful mafia boss when she sets out to uncover the truth behind her father's mysterious death.)*

# %%
messages =[]
add_user_message(
    messages, 
    "Wrtie a one sentence description of a fake database"
)

stream = client.messages.create(
    model=model,
    messages=messages,
    max_tokens=1000,
    stream=True
)

for event in stream:
    print(event)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 messages =[]
# ----> 2 add_user_message(
#       3     messages,
#       4     "Wrtie a one sentence description of a fake database"
#       5 )
#       7 stream = client.messages.create(
#       8     model=model,
#       9     messages=messages,
#      10     max_tokens=1000,
#      11     stream=True
#      12 )
#      14 for event in stream:
#
# NameError: name 'add_user_message' is not defined

# %%
messages =[]
add_user_message(
    messages, 
    "Wrtie a one sentence description of a fake database"
)

with client.messages.stream(
    model=model,
    messages=messages,
    max_tokens=1000
) as stream:
    for text in stream.text_stream:
        # print(text, end="")
        pass

stream.get_final_message()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 messages =[]
# ----> 2 add_user_message(
#       3     messages,
#       4     "Wrtie a one sentence description of a fake database"
#       5 )
#       7 with client.messages.stream(
#       8     model=model,
#       9     messages=messages,
#      10     max_tokens=1000
#      11 ) as stream:
#      12     for text in stream.text_stream:
#      13         # print(text, end="")
#
# NameError: name 'add_user_message' is not defined

# %%
messages =[]
add_user_message(
    messages, 
    "Generate a very short event bridge rule as json"
)

add_assistant_message(messages, "```json")
text = chat(messages, stop_sequences=["```"])

print(answer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       2 add_user_message(
#       3     messages,
#       4     "Generate a very short event bridge rule as json"
#       5 )
#       7 add_assistant_message(messages, "```json")
# ----> 8 text = chat(messages, stop_sequences=["```"])
#      10 print(answer)
#
# TypeError: chat() got an unexpected keyword argument 'stop_sequences'
